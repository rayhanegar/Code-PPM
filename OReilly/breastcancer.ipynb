# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

# %%
cancer = load_breast_cancer()
cancerdf = pd.DataFrame(cancer.data, columns=cancer.feature_names)
cancerdf["target"] = cancer.target

# %%
cancerdf.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
cancer_0 = cancerdf[cancerdf['target']==0]
cancer_1 = cancerdf[cancerdf['target']==1]
sampled_cancer_0 = resample(cancer_0, replace=False, n_samples=25)
sampled_cancer_1 = resample(cancer_1, replace=False, n_samples=25)
cancer_50 = pd.concat([sampled_cancer_0, sampled_cancer_1])

# %%
cancer_50
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 499       20.590         21.24          137.80     1320.0          0.10850
# 82        25.220         24.91          171.50     1878.0          0.10630
# 199       14.450         20.22           94.49      642.7          0.09872
# 351       15.750         19.22          107.10      758.6          0.12430
# 182       15.700         20.31          101.20      766.6          0.09597
# 389       19.550         23.21          128.90     1174.0          0.10100
# 430       14.900         22.53          102.10      685.0          0.09947
# 489       16.690         20.20          107.10      857.6          0.07497
# 441       17.270         25.42          112.40      928.8          0.08331
# 566       16.600         28.08          108.30      858.1          0.08455
# 2         19.690         21.25          130.00     1203.0          0.10960
# ...

# %%
cancer_50.to_excel('cancer_50.xlsx', index=False)
